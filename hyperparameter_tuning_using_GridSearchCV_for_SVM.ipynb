# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Read the csv file and checking the first five observation

# %%
df = pd.read_csv('coalv2.csv')
df.head()
# Out:
#    moistr  volmat  fixedc    ash  hydrgn  carbon  nitrgn  oxygen  sulfur  \
# 0    6.98   33.02   57.42   2.58    5.14   71.80    1.13   18.91    0.44
# 1   11.15   26.39   58.32   4.14    5.05   66.71    1.40   22.10    0.60
# 2    2.38   29.88   54.64  13.10    4.66   69.69    1.25    6.07    5.23
# 3    3.38   28.61   40.39  27.62    4.30   55.02    1.15    6.78    5.13
# 4   10.67   27.92   54.50   6.91    5.43   70.17    1.54   14.80    1.15
#
#      gcv
# 0  12312
# 1  11290
# 2  12674
# 3  10130
# 4  12559

# %%
df = df.iloc[:5000, ]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   moistr  5000 non-null   float64
#  1   volmat  5000 non-null   float64
#  2   fixedc  5000 non-null   float64
#  3   ash     5000 non-null   float64
#  4   hydrgn  5000 non-null   float64
#  5   carbon  5000 non-null   float64
#  6   nitrgn  5000 non-null   float64
#  7   oxygen  5000 non-null   float64
#  8   sulfur  5000 non-null   float64
#  9   gcv     5000 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 390.8 KB

# %%
# selecting features and label
X = df.iloc[:, :-1]  # features
y = df.iloc[:,-1]  #label

# %%
[X.shape,y.shape]
# Out:
# [(5000, 9), (5000,)]

# %% [markdown]
# ___
# ###  Standardization:
# $$x^{'} = \frac{x - \bar{x}}{\sigma}$$
#
# where,
# $\bar{x}$ = mean of a certain feature
# $\sigma$ = standard deviation of a certain feature
# ___

# %%
# Standardization
from sklearn.preprocessing import StandardScaler

# transforming X_train value to feed to the model
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# transforming X_test value for predicting for new cases
#X_test_scaled = scaler.transform(X_test)

# %%
# function to convert seconds to into hours, minutes and seconds
# this function is used to measure the time taking by the models
def convert(seconds):
    seconds = seconds % (24 * 3600)
    hour = seconds // 3600
    seconds %= 3600
    minutes = seconds // 60
    seconds %= 60
      
    return "%d:%02d:%02d" % (hour, minutes, seconds)

# %% [markdown]
# ### GridSearchCV (Hyperparameter Tuning)
# - parameter that's been selected for tuning
#     1. C
#     2. gamma
#     3. kernel

# %%
# Loading the svr model from svm and GridSearchCV from model_selection
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import time
start = time.time()
# enter your code below this line

regr = GridSearchCV(SVR(), {
    'gamma' : ['scale', 'auto'],
    'C': [1, 5, 10, 15, 20,],
    'kernel': ['rbf','linear', 'poly', 'sigmoid']
}, cv=10, return_train_score=False, scoring=['neg_mean_squared_error', 'r2'], refit='r2')

#Fit the model
regr.fit(X_scaled, y)

# enter you code above this line    
end = time.time()

regr.cv_results_
# Out:
# {'mean_fit_time': array([2.38140121, 1.31229677, 1.42389886, 2.22017622, 1.93991015,
#         1.35789051, 1.50719531, 2.56750009, 2.28009381, 1.88149581,
#         1.61139445, 1.80939319, 1.91489542, 1.4422487 , 1.3774992 ,
#         1.82059553, 1.73469615, 1.95099816, 1.81010044, 1.73428886,
#         1.69460292, 1.38539882, 1.36490214, 1.72069921, 1.75099485,
#         1.47170005, 1.32979732, 1.88270297, 1.99004741, 1.52799075,
#         1.58379755, 2.21429944, 1.99699974, 1.4903018 , 1.51719797,
#         1.82259197, 1.74360218, 1.38389816, 1.38699362, 1.72349541]),
#  'std_fit_time': array([0.55643637, 0.18012119, 0.11222761, 0.46353101, 0.08668069,
#         0.03583796, 0.10850823, 0.48870759, 0.39304528, 0.43703211,
#         0.33059442, 0.18098082, 0.19305965, 0.11867576, 0.10009252,
#         0.15370575, 0.06584304, 0.34035487, 0.24483629, 0.11481844,
#         0.06569023, 0.11232514, 0.17017522, 0.05919281, 0.08238938,
#         0.175685  , 0.05223731, 0.18342695, 0.26590363, 0.10477711,
#         0.18737431, 0.10887911, 0.26921639, 0.06987987, 0.10380068,
#         0.12356817, 0.05363669, 0.03241039, 0.11328382, 0.08099116]),
#  'mean_score_time': array([0.44902649, 0.0925035 , 0.1027    , 0.18319588, 0.41039991,
#         0.10350695, 0.11550393, 0.19850008, 0.45910404, 0.14190433,
#         0.12760313, 0.15250742, 0.40620461, 0.10000403, 0.10909944,
#         0.15960355, 0.35760303, 0.13060105, 0.1187994 , 0.14300902,
#         0.35480187, 0.09000039, 0.1030973 , 0.14359972, 0.34670503,
#         0.09879959, 0.09809992, 0.15179479, 0.40820942, 0.10490892,
#         0.12130044, 0.17220137, 0.38169858, 0.09629698, 0.12510183,
#         0.14210775, 0.34969962, 0.08910043, 0.10280256, 0.14310346]),
#  'std_score_time': array([0.07833945, 0.01000872, 0.00833824, 0.03931204, 0.05619239,
#         0.01307638, 0.01013174, 0.04498644, 0.09917462, 0.04917486,
#         0.04052334, 0.01502031, 0.05525064, 0.02947544, 0.01879794,
#         0.02440205, 0.02359516, 0.04081989, 0.01972043, 0.00850318,
#         0.02906217, 0.00456475, 0.01361219, 0.0067854 , 0.02390812,
#         0.01371312, 0.00339048, 0.01524802, 0.07944844, 0.01934102,
#         0.02487138, 0.02398691, 0.04530923, 0.013132  , 0.02163486,
#         0.0071935 , 0.01563927, 0.00562963, 0.00555959, 0.00570299]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 1, 1, 1, 1, 5, 5, 5, 5, 5, 5, 5, 5, 10, 10,
#                     10, 10, 10, 10, 10, 10, 15, 15, 15, 15, 15, 15, 15, 15,
#                     20, 20, 20, 20, 20, 20, 20, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_gamma': masked_array(data=['scale', 'scale', 'scale', 'scale', 'auto', 'auto',
#                     'auto', 'auto', 'scale', 'scale', 'scale', 'scale',
#                     'auto', 'auto', 'auto', 'auto', 'scale', 'scale',
#                     'scale', 'scale', 'auto', 'auto', 'auto', 'auto',
#                     'scale', 'scale', 'scale', 'scale', 'auto', 'auto',
#                     'auto', 'auto', 'scale', 'scale', 'scale', 'scale',
#                     'auto', 'auto', 'auto', 'auto'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'poly', 'sigmoid', 'rbf', 'linear',
#                     'poly', 'sigmoid', 'rbf', 'linear', 'poly', 'sigmoid',
#                     'rbf', 'linear', 'poly', 'sigmoid', 'rbf', 'linear',
#                     'poly', 'sigmoid', 'rbf', 'linear', 'poly', 'sigmoid',
#                     'rbf', 'linear', 'poly', 'sigmoid', 'rbf', 'linear',
#                     'poly', 'sigmoid', 'rbf', 'linear', 'poly', 'sigmoid',
#                     'rbf', 'linear', 'poly', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 1, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 5, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 5, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 5, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 5, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 5, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 5, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 5, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 15, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 15, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 15, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 15, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 15, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 15, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 15, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 15, 'gamma': 'auto', 'kernel': 'sigmoid'},
#   {'C': 20, 'gamma': 'scale', 'kernel': 'rbf'},
#   {'C': 20, 'gamma': 'scale', 'kernel': 'linear'},
#   {'C': 20, 'gamma': 'scale', 'kernel': 'poly'},
#   {'C': 20, 'gamma': 'scale', 'kernel': 'sigmoid'},
#   {'C': 20, 'gamma': 'auto', 'kernel': 'rbf'},
#   {'C': 20, 'gamma': 'auto', 'kernel': 'linear'},
#   {'C': 20, 'gamma': 'auto', 'kernel': 'poly'},
#   {'C': 20, 'gamma': 'auto', 'kernel': 'sigmoid'}],
#  'split0_test_neg_mean_squared_error': array([-2491157.45209713,   -25734.13888988, -1545017.32420999,
#         -1213281.30850618, -2495396.98130374,   -25734.13888988,
#         -1523246.66202939, -1196579.59102283, -1058306.43740576,
#           -14178.61594186,  -921668.99237671,  -452653.71448071,
#         -1069432.42147491,   -14178.61594186,  -895183.50294934,
#          -464120.16364696,  -657354.81104613,   -13934.24304111,
#          -719282.65647271,  -886960.34837929,  -666304.95109789,
#           -13934.24304111,  -707419.69552309,  -913953.5859995 ,
#          -482399.77132778,   -13861.09610218,  -679009.79193763,
#         -1465673.03736013,  -489948.12771098,   -13861.09610218,
#          -675589.00469366, -1510642.799611  ,  -388173.51818394,
#           -13756.34191519,  -671507.3700991 , -2172102.91263899,
#          -394627.97782469,   -13756.34191519,  -672647.66524142,
#         -2220030.06067552]),
#         0.83248043, 0.98908401, 0.75033436, 0.81709971, 0.8617311 ,
#         0.98861863, 0.74349178, 0.62466285, 0.86396925, 0.98861863,
#         0.74552567, 0.64905713, 0.87888665, 0.98830592, 0.74506568,
#         0.3851247 , 0.88116921, 0.98830592, 0.74647602, 0.42339229]),
#  'mean_test_r2': array([-0.03025052,  0.98647769,  0.33969977,  0.48835934, -0.02583008,
#          0.98647769,  0.33684089,  0.48247914,  0.59996346,  0.99256654,
#          0.42112365,  0.84838434,  0.61157387,  0.99256654,  0.41227325,
#          0.86131518,  0.78001891,  0.99277318,  0.43960554,  0.66624006,
#          0.78723698,  0.99277318,  0.4453576 ,  0.6753203 ,  0.8502164 ,
#          0.99279325,  0.46201245,  0.36382553,  0.85504596,  0.99279325,
#          0.47304192,  0.37224759,  0.88402872,  0.99277921,  0.47968633,
#         -0.04913815,  0.88800425,  0.99277921,  0.48679448, -0.02670475]),
#  'std_test_r2': array([0.5569349 , 0.00678895, 0.18811135, 0.28356386, 0.54753609,
#         0.00678895, 0.18382569, 0.31234886, 0.31636035, 0.00427676,
#         0.35418638, 0.1299408 , 0.289813  , 0.00427676, 0.36017189,
#         0.09906545, 0.1729537 , 0.00435698, 0.38714462, 0.26132451,
#         0.15651358, 0.00435698, 0.36513122, 0.21485137, 0.11225244,
#         0.00441367, 0.34901277, 0.47590029, 0.09998586, 0.00441367,
#         0.32218777, 0.39127114, 0.0789748 , 0.00447304, 0.31353488,
#         0.75392136, 0.06887771, 0.00447304, 0.30665184, 0.61652984]),
#  'rank_test_r2': array([39,  9, 35, 23, 37,  9, 36, 25, 22,  7, 31, 16, 21,  7, 32, 13, 18,
#          5, 30, 20, 17,  5, 29, 19, 15,  1, 28, 34, 14,  1, 27, 33, 12,  3,
#         26, 40, 11,  3, 24, 38])}

# %%
# import sklearn
# sorted(sklearn.metrics.SCORERS.keys())

# %% [markdown]
# ### Total Run Time:

# %%
print('run_time:', convert(end-start), 'h:m:s')
# Out:
# run_time: 0:12:49 h:m:s

# %%
# converting the above gibrish to a readable format using dataFrame
df = pd.DataFrame(regr.cv_results_)
print(df.shape)
df2 = df.transpose()
df2
# Out:
# (40, 34)
#                                                                              0   \
# mean_fit_time                                                          2.381401
# std_fit_time                                                           0.556436
# mean_score_time                                                        0.449026
# std_score_time                                                         0.078339
# param_C                                                                       1
# param_gamma                                                               scale
# param_kernel                                                                rbf
# params                              {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# split0_test_neg_mean_squared_error                              -2491157.452097
# split1_test_neg_mean_squared_error                              -1752506.763586
# split2_test_neg_mean_squared_error                              -6694853.860532
# split3_test_neg_mean_squared_error                              -1308963.048779
# split4_test_neg_mean_squared_error                               -837627.334194
# split5_test_neg_mean_squared_error                             -10248436.498346
# split6_test_neg_mean_squared_error                             -16005678.417753
# split7_test_neg_mean_squared_error                               -455430.603241
# split8_test_neg_mean_squared_error                              -1006923.552607
# split9_test_neg_mean_squared_error                              -2630563.107847
# mean_test_neg_mean_squared_error                                -4343214.063898
# std_test_neg_mean_squared_error                                  4870641.641506
# rank_test_neg_mean_squared_error                                             39
# split0_test_r2                                                         0.214396
# split1_test_r2                                                          0.36918
# split2_test_r2                                                        -0.151012
# split3_test_r2                                                         0.377977
# split4_test_r2                                                         0.313584
# split5_test_r2                                                        -0.836496
# split6_test_r2                                                        -1.302438
# split7_test_r2                                                          0.42666
# split8_test_r2                                                        -0.008417
# split9_test_r2                                                         0.294061
# mean_test_r2                                                          -0.030251
# std_test_r2                                                            0.556935
# rank_test_r2                                                                 39
#
#                                                                                 1   \
# mean_fit_time                                                             1.312297
# std_fit_time                                                              0.180121
# mean_score_time                                                           0.092503
# std_score_time                                                            0.010009
# param_C                                                                          1
# param_gamma                                                                  scale
# param_kernel                                                                linear
# params                              {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# split0_test_neg_mean_squared_error                                    -25734.13889
# split1_test_neg_mean_squared_error                                   -28126.398502
# split2_test_neg_mean_squared_error                                   -84669.073151
# split3_test_neg_mean_squared_error                                   -27159.108458
# split4_test_neg_mean_squared_error                                   -14460.163887
# split5_test_neg_mean_squared_error                                   -40023.568692
# split6_test_neg_mean_squared_error                                    -45022.15453
# split7_test_neg_mean_squared_error                                    -20721.66498
# split8_test_neg_mean_squared_error                                   -26302.330527
# split9_test_neg_mean_squared_error                                    -43205.07118
# mean_test_neg_mean_squared_error                                      -35542.36728
# std_test_neg_mean_squared_error                                       18849.577063
# rank_test_neg_mean_squared_error                                                 9
# split0_test_r2                                                            0.991885
# split1_test_r2                                                            0.989876
# split2_test_r2                                                            0.985443
# split3_test_r2                                                            0.987094
# split4_test_r2                                                             0.98815
# split5_test_r2                                                            0.992828
# split6_test_r2                                                            0.993524
# split7_test_r2                                                            0.973914
# split8_test_r2                                                            0.973659
# split9_test_r2                                                            0.988405
# mean_test_r2                                                              0.986478
# std_test_r2                                                               0.006789
# rank_test_r2                                                                     9
#
#                                                                               2   \
# mean_fit_time                                                           1.423899
# std_fit_time                                                            0.112228
# mean_score_time                                                           0.1027
# std_score_time                                                          0.008338
# param_C                                                                        1
# param_gamma                                                                scale
# param_kernel                                                                poly
# params                              {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# split0_test_neg_mean_squared_error                                -1545017.32421
# split1_test_neg_mean_squared_error                               -1503634.865313
# split2_test_neg_mean_squared_error                               -3519968.744542
# split3_test_neg_mean_squared_error                               -1287913.949001
# split4_test_neg_mean_squared_error                               -1037222.008132
# split5_test_neg_mean_squared_error                               -4348110.860384
# split6_test_neg_mean_squared_error                                -3375780.11173
# split7_test_neg_mean_squared_error                                -755861.948396
# split8_test_neg_mean_squared_error                                -907293.898376
# split9_test_neg_mean_squared_error                               -1424906.626978
# mean_test_neg_mean_squared_error                                 -1970571.033706
# std_test_neg_mean_squared_error                                   1211117.416431
# rank_test_neg_mean_squared_error                                              31
# split0_test_r2                                                          0.512768
# split1_test_r2                                                          0.458762
# split2_test_r2                                                           0.39483
# split3_test_r2                                                          0.387979
# split4_test_r2                                                           0.15002
# split5_test_r2                                                          0.220829
# split6_test_r2                                                           0.51439
# split7_test_r2                                                          0.048448
# split8_test_r2                                                          0.091361
# split9_test_r2                                                          0.617612
# mean_test_r2                                                              0.3397
# std_test_r2                                                             0.188111
# rank_test_r2                                                                  35
#
#                                                                                  3   \
# mean_fit_time                                                              2.220176
# std_fit_time                                                               0.463531
# mean_score_time                                                            0.183196
# std_score_time                                                             0.039312
# param_C                                                                           1
# param_gamma                                                                   scale
# param_kernel                                                                sigmoid
# params                              {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# split0_test_neg_mean_squared_error                                  -1213281.308506
# split1_test_neg_mean_squared_error                                   -872820.861289
# split2_test_neg_mean_squared_error                                  -3366896.524818
# split3_test_neg_mean_squared_error                                   -610194.498505
# split4_test_neg_mean_squared_error                                   -442720.401506
# split5_test_neg_mean_squared_error                                  -5225879.094423
# split6_test_neg_mean_squared_error                                  -8000478.556253
# split7_test_neg_mean_squared_error                                   -243455.786643
# split8_test_neg_mean_squared_error                                   -483533.595894
# split9_test_neg_mean_squared_error                                  -1154848.439041
# mean_test_neg_mean_squared_error                                    -2161410.906688
# std_test_neg_mean_squared_error                                      2456938.082591
# rank_test_neg_mean_squared_error                                                 33
# split0_test_r2                                                             0.617383
# split1_test_r2                                                             0.685825
# split2_test_r2                                                             0.421147
# split3_test_r2                                                             0.710034
# split4_test_r2                                                             0.637201
# split5_test_r2                                                             0.063535
# split6_test_r2                                                            -0.150879
# split7_test_r2                                                             0.693514
# split8_test_r2                                                             0.515749
# split9_test_r2                                                             0.690084
# mean_test_r2                                                               0.488359
# std_test_r2                                                                0.283564
# rank_test_r2                                                                     23
#
#                                                                             4   \
# mean_fit_time                                                          1.93991
# std_fit_time                                                          0.086681
# mean_score_time                                                         0.4104
# std_score_time                                                        0.056192
# param_C                                                                      1
# param_gamma                                                               auto
# param_kernel                                                               rbf
# params                              {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# split0_test_neg_mean_squared_error                             -2495396.981304
# split1_test_neg_mean_squared_error                             -1758824.679906
# split2_test_neg_mean_squared_error                             -6680198.619552
# split3_test_neg_mean_squared_error                             -1312369.446869
# split4_test_neg_mean_squared_error                              -836947.915962
# split5_test_neg_mean_squared_error                            -10151985.157018
# split6_test_neg_mean_squared_error                            -15803566.080041
# split7_test_neg_mean_squared_error                              -455937.235007
# split8_test_neg_mean_squared_error                             -1008985.077394
# split9_test_neg_mean_squared_error                             -2620493.819344
# mean_test_neg_mean_squared_error                                -4312470.50124
# std_test_neg_mean_squared_error                                 4809394.162101
# rank_test_neg_mean_squared_error                                            38
# split0_test_r2                                                        0.213059
# split1_test_r2                                                        0.366906
# split2_test_r2                                                       -0.148492
# split3_test_r2                                                        0.376358
# split4_test_r2                                                         0.31414
# split5_test_r2                                                       -0.819212
# split6_test_r2                                                       -1.273364
# split7_test_r2                                                        0.426022
# split8_test_r2                                                       -0.010481
# split9_test_r2                                                        0.296763
# mean_test_r2                                                          -0.02583
# std_test_r2                                                           0.547536
# rank_test_r2                                                                37
#
#                                                                                5   \
# mean_fit_time                                                            1.357891
# std_fit_time                                                             0.035838
# mean_score_time                                                          0.103507
# std_score_time                                                           0.013076
# param_C                                                                         1
# param_gamma                                                                  auto
# param_kernel                                                               linear
# params                              {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# split0_test_neg_mean_squared_error                                   -25734.13889
# split1_test_neg_mean_squared_error                                  -28126.398502
# split2_test_neg_mean_squared_error                                  -84669.073151
# split3_test_neg_mean_squared_error                                  -27159.108458
# split4_test_neg_mean_squared_error                                  -14460.163887
# split5_test_neg_mean_squared_error                                  -40023.568692
# split6_test_neg_mean_squared_error                                   -45022.15453
# split7_test_neg_mean_squared_error                                   -20721.66498
# split8_test_neg_mean_squared_error                                  -26302.330527
# split9_test_neg_mean_squared_error                                   -43205.07118
# mean_test_neg_mean_squared_error                                     -35542.36728
# std_test_neg_mean_squared_error                                      18849.577063
# rank_test_neg_mean_squared_error                                                9
# split0_test_r2                                                           0.991885
# split1_test_r2                                                           0.989876
# split2_test_r2                                                           0.985443
# split3_test_r2                                                           0.987094
# split4_test_r2                                                            0.98815
# split5_test_r2                                                           0.992828
# split6_test_r2                                                           0.993524
# split7_test_r2                                                           0.973914
# split8_test_r2                                                           0.973659
# split9_test_r2                                                           0.988405
# mean_test_r2                                                             0.986478
# std_test_r2                                                              0.006789
# rank_test_r2                                                                    9
#
#                                                                              6   \
# mean_fit_time                                                          1.507195
# std_fit_time                                                           0.108508
# mean_score_time                                                        0.115504
# std_score_time                                                         0.010132
# param_C                                                                       1
# param_gamma                                                                auto
# param_kernel                                                               poly
# params                              {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# split0_test_neg_mean_squared_error                              -1523246.662029
# split1_test_neg_mean_squared_error                               -1458482.13823
# split2_test_neg_mean_squared_error                              -3545250.364398
# split3_test_neg_mean_squared_error                              -1261456.248791
# split4_test_neg_mean_squared_error                               -994270.128174
# split5_test_neg_mean_squared_error                              -4514060.736517
# split6_test_neg_mean_squared_error                              -3761840.486335
# split7_test_neg_mean_squared_error                               -770516.537366
# split8_test_neg_mean_squared_error                               -889141.832996
# split9_test_neg_mean_squared_error                              -1460637.582379
# mean_test_neg_mean_squared_error                                -2017890.271722
# std_test_neg_mean_squared_error                                  1300892.132872
# rank_test_neg_mean_squared_error                                             32
# split0_test_r2                                                         0.519633
# split1_test_r2                                                         0.475015
# split2_test_r2                                                         0.390483
# split3_test_r2                                                         0.400552
# split4_test_r2                                                         0.185218
# split5_test_r2                                                         0.191091
# split6_test_r2                                                         0.458854
# split7_test_r2                                                         0.029999
# split8_test_r2                                                          0.10954
# split9_test_r2                                                         0.608023
# mean_test_r2                                                           0.336841
# std_test_r2                                                            0.183826
# rank_test_r2                                                                 36
#
#                                                                                 7   \
# mean_fit_time                                                               2.5675
# std_fit_time                                                              0.488708
# mean_score_time                                                             0.1985
# std_score_time                                                            0.044986
# param_C                                                                          1
# param_gamma                                                                   auto
# param_kernel                                                               sigmoid
# params                              {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# split0_test_neg_mean_squared_error                                 -1196579.591023
# split1_test_neg_mean_squared_error                                  -842900.801752
# split2_test_neg_mean_squared_error                                 -3417368.007533
# split3_test_neg_mean_squared_error                                  -586880.086616
# split4_test_neg_mean_squared_error                                  -415146.470296
# split5_test_neg_mean_squared_error                                 -5485518.912703
# split6_test_neg_mean_squared_error                                 -8538703.473362
# split7_test_neg_mean_squared_error                                  -228949.072113
# split8_test_neg_mean_squared_error                                  -470741.493356
# split9_test_neg_mean_squared_error                                 -1180780.398592
# mean_test_neg_mean_squared_error                                   -2236356.830735
# std_test_neg_mean_squared_error                                     2626655.230341
# rank_test_neg_mean_squared_error                                                34
# split0_test_r2                                                             0.62265
# split1_test_r2                                                            0.696595
# split2_test_r2                                                            0.412469
# split3_test_r2                                                            0.721113
# split4_test_r2                                                            0.659797
# split5_test_r2                                                            0.017008
# split6_test_r2                                                           -0.228304
# split7_test_r2                                                            0.711777
# split8_test_r2                                                            0.528561
# split9_test_r2                                                            0.683125
# mean_test_r2                                                              0.482479
# std_test_r2                                                               0.312349
# rank_test_r2                                                                    25
#
#                                                                              8   \
# mean_fit_time                                                          2.280094
# std_fit_time                                                           0.393045
# mean_score_time                                                        0.459104
# std_score_time                                                         0.099175
# param_C                                                                       5
# param_gamma                                                               scale
# param_kernel                                                                rbf
# params                              {'C': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# split0_test_neg_mean_squared_error                              -1058306.437406
# split1_test_neg_mean_squared_error                               -466631.461117
# split2_test_neg_mean_squared_error                              -2650294.465184
# split3_test_neg_mean_squared_error                               -412915.471169
# split4_test_neg_mean_squared_error                               -156319.343914
# split5_test_neg_mean_squared_error                              -4018152.710511
# split6_test_neg_mean_squared_error                              -8365272.689354
# split7_test_neg_mean_squared_error                               -125589.259135
# split8_test_neg_mean_squared_error                               -365373.680836
# split9_test_neg_mean_squared_error                              -1010830.589411
# mean_test_neg_mean_squared_error                                -1862968.610804
# std_test_neg_mean_squared_error                                   2472743.82225
# rank_test_neg_mean_squared_error                                             30
# split0_test_r2                                                         0.666256
# split1_test_r2                                                         0.832035
# split2_test_r2                                                         0.544348
# split3_test_r2                                                         0.803781
# split4_test_r2                                                           0.8719
# split5_test_r2                                                         0.279956
# split6_test_r2                                                        -0.203355
# split7_test_r2                                                         0.841896
# split8_test_r2                                                         0.634085
# split9_test_r2                                                         0.728733
# mean_test_r2                                                           0.599963
# std_test_r2                                                             0.31636
# rank_test_r2                                                                 22
#
#                                                                                 9   \
# mean_fit_time                                                             1.881496
# std_fit_time                                                              0.437032
# mean_score_time                                                           0.141904
# std_score_time                                                            0.049175
# param_C                                                                          5
# param_gamma                                                                  scale
# param_kernel                                                                linear
# params                              {'C': 5, 'gamma': 'scale', 'kernel': 'linear'}
# split0_test_neg_mean_squared_error                                   -14178.615942
# split1_test_neg_mean_squared_error                                   -11485.196613
# split2_test_neg_mean_squared_error                                   -35734.415492
# split3_test_neg_mean_squared_error                                   -14095.385754
# split4_test_neg_mean_squared_error                                   -10882.449909
# split5_test_neg_mean_squared_error                                   -13846.779612
# split6_test_neg_mean_squared_error                                   -18010.268629
# split7_test_neg_mean_squared_error                                    -12849.86396
# split8_test_neg_mean_squared_error                                   -12679.432848
# split9_test_neg_mean_squared_error                                   -37346.713836
# mean_test_neg_mean_squared_error                                      -18110.91226
# std_test_neg_mean_squared_error                                        9400.609905
# rank_test_neg_mean_squared_error                                                 7
# split0_test_r2                                                            0.995529
# split1_test_r2                                                            0.995866
# split2_test_r2                                                            0.993856
# split3_test_r2                                                            0.993302
# split4_test_r2                                                            0.991082
# split5_test_r2                                                            0.997519
# split6_test_r2                                                            0.997409
# split7_test_r2                                                            0.983823
# split8_test_r2                                                            0.987302
# split9_test_r2                                                            0.989978
# mean_test_r2                                                              0.992567
# std_test_r2                                                               0.004277
# rank_test_r2                                                                     7
#
#                                     ...  \
# mean_fit_time                       ...
# std_fit_time                        ...
# mean_score_time                     ...
# std_score_time                      ...
# param_C                             ...
# param_gamma                         ...
# param_kernel                        ...
# params                              ...
# split0_test_neg_mean_squared_error  ...
# split1_test_neg_mean_squared_error  ...
# split2_test_neg_mean_squared_error  ...
# split3_test_neg_mean_squared_error  ...
# split4_test_neg_mean_squared_error  ...
# split5_test_neg_mean_squared_error  ...
# split6_test_neg_mean_squared_error  ...
# split7_test_neg_mean_squared_error  ...
# split8_test_neg_mean_squared_error  ...
# split9_test_neg_mean_squared_error  ...
# mean_test_neg_mean_squared_error    ...
# std_test_neg_mean_squared_error     ...
# rank_test_neg_mean_squared_error    ...
# split0_test_r2                      ...
# split1_test_r2                      ...
# split2_test_r2                      ...
# split3_test_r2                      ...
# split4_test_r2                      ...
# split5_test_r2                      ...
# split6_test_r2                      ...
# split7_test_r2                      ...
# split8_test_r2                      ...
# split9_test_r2                      ...
# mean_test_r2                        ...
# std_test_r2                         ...
# rank_test_r2                        ...
#
#                                                                               30  \
# mean_fit_time                                                           1.583798
# std_fit_time                                                            0.187374
# mean_score_time                                                           0.1213
# std_score_time                                                          0.024871
# param_C                                                                       15
# param_gamma                                                                 auto
# param_kernel                                                                poly
# params                              {'C': 15, 'gamma': 'auto', 'kernel': 'poly'}
# split0_test_neg_mean_squared_error                                -675589.004694
# split1_test_neg_mean_squared_error                                -716595.722921
# split2_test_neg_mean_squared_error                               -2359062.521046
# split3_test_neg_mean_squared_error                               -2198942.925013
# split4_test_neg_mean_squared_error                                -550115.990781
# split5_test_neg_mean_squared_error                               -2559177.622495
# split6_test_neg_mean_squared_error                               -2550808.895153
# split7_test_neg_mean_squared_error                                -961673.423821
# split8_test_neg_mean_squared_error                                -605698.730168
# split9_test_neg_mean_squared_error                                 -948255.93933
# mean_test_neg_mean_squared_error                                 -1412592.077542
# std_test_neg_mean_squared_error                                    834614.396135
# rank_test_neg_mean_squared_error                                              21
# split0_test_r2                                                          0.786948
# split1_test_r2                                                          0.742059
# split2_test_r2                                                          0.594418
# split3_test_r2                                                         -0.044944
# split4_test_r2                                                          0.549193
# split5_test_r2                                                          0.541401
# split6_test_r2                                                          0.633063
# split7_test_r2                                                         -0.210648
# split8_test_r2                                                          0.393403
# split9_test_r2                                                          0.745526
# mean_test_r2                                                            0.473042
# std_test_r2                                                             0.322188
# rank_test_r2                                                                  27
#
#                                                                                  31  \
# mean_fit_time                                                              2.214299
# std_fit_time                                                               0.108879
# mean_score_time                                                            0.172201
# std_score_time                                                             0.023987
# param_C                                                                          15
# param_gamma                                                                    auto
# param_kernel                                                                sigmoid
# params                              {'C': 15, 'gamma': 'auto', 'kernel': 'sigmoid'}
# split0_test_neg_mean_squared_error                                  -1510642.799611
# split1_test_neg_mean_squared_error                                   -537706.520725
# split2_test_neg_mean_squared_error                                  -4477357.267369
# split3_test_neg_mean_squared_error                                  -1451449.486742
# split4_test_neg_mean_squared_error                                   -228864.407737
# split5_test_neg_mean_squared_error                                  -5913899.682683
# split6_test_neg_mean_squared_error                                 -10395702.904292
# split7_test_neg_mean_squared_error                                   -562367.464727
# split8_test_neg_mean_squared_error                                   -345920.760339
# split9_test_neg_mean_squared_error                                  -1307729.787533
# mean_test_neg_mean_squared_error                                    -2673164.108176
# std_test_neg_mean_squared_error                                      3138627.772986
# rank_test_neg_mean_squared_error                                                 35
# split0_test_r2                                                             0.523608
# split1_test_r2                                                             0.806451
# split2_test_r2                                                             0.230231
# split3_test_r2                                                             0.310267
# split4_test_r2                                                             0.812451
# split5_test_r2                                                            -0.059757
# split6_test_r2                                                            -0.495435
# split7_test_r2                                                             0.292037
# split8_test_r2                                                             0.653566
# split9_test_r2                                                             0.649057
# mean_test_r2                                                               0.372248
# std_test_r2                                                                0.391271
# rank_test_r2                                                                     33
#
#                                                                               32  \
# mean_fit_time                                                              1.997
# std_fit_time                                                            0.269216
# mean_score_time                                                         0.381699
# std_score_time                                                          0.045309
# param_C                                                                       20
# param_gamma                                                                scale
# param_kernel                                                                 rbf
# params                              {'C': 20, 'gamma': 'scale', 'kernel': 'rbf'}
# split0_test_neg_mean_squared_error                                -388173.518184
# split1_test_neg_mean_squared_error                                -145006.275984
# split2_test_neg_mean_squared_error                                -820787.560441
# split3_test_neg_mean_squared_error                                -185306.099083
# split4_test_neg_mean_squared_error                                 -35769.725973
# split5_test_neg_mean_squared_error                                -612111.319001
# split6_test_neg_mean_squared_error                               -2302842.721118
# split7_test_neg_mean_squared_error                                 -51020.130547
# split8_test_neg_mean_squared_error                                 -100172.97673
# split9_test_neg_mean_squared_error                                -451308.609019
# mean_test_neg_mean_squared_error                                  -509249.893608
# std_test_neg_mean_squared_error                                    646663.978164
# rank_test_neg_mean_squared_error                                              12
# split0_test_r2                                                          0.877587
# split1_test_r2                                                          0.947805
# split2_test_r2                                                          0.858886
# split3_test_r2                                                          0.911942
# split4_test_r2                                                          0.970688
# split5_test_r2                                                          0.890311
# split6_test_r2                                                          0.668733
# split7_test_r2                                                          0.935771
# split8_test_r2                                                          0.899678
# split9_test_r2                                                          0.878887
# mean_test_r2                                                            0.884029
# std_test_r2                                                             0.078975
# rank_test_r2                                                                  12
#
#                                                                                  33  \
# mean_fit_time                                                              1.490302
# std_fit_time                                                                0.06988
# mean_score_time                                                            0.096297
# std_score_time                                                             0.013132
# param_C                                                                          20
# param_gamma                                                                   scale
# param_kernel                                                                 linear
# params                              {'C': 20, 'gamma': 'scale', 'kernel': 'linear'}
# split0_test_neg_mean_squared_error                                    -13756.341915
# split1_test_neg_mean_squared_error                                     -9607.697111
# split2_test_neg_mean_squared_error                                    -28775.028611
# split3_test_neg_mean_squared_error                                    -13487.309235
# split4_test_neg_mean_squared_error                                    -11057.818584
# split5_test_neg_mean_squared_error                                    -12828.957647
# split6_test_neg_mean_squared_error                                    -15299.124809
# split7_test_neg_mean_squared_error                                    -12794.546696
# split8_test_neg_mean_squared_error                                    -11675.348188
# split9_test_neg_mean_squared_error                                     -43576.03895
# mean_test_neg_mean_squared_error                                      -17285.821175
# std_test_neg_mean_squared_error                                        10115.653755
# rank_test_neg_mean_squared_error                                                  3
# split0_test_r2                                                             0.995662
# split1_test_r2                                                             0.996542
# split2_test_r2                                                             0.995053
# split3_test_r2                                                             0.993591
# split4_test_r2                                                             0.990938
# split5_test_r2                                                             0.997701
# split6_test_r2                                                             0.997799
# split7_test_r2                                                             0.983893
# split8_test_r2                                                             0.988307
# split9_test_r2                                                             0.988306
# mean_test_r2                                                               0.992779
# std_test_r2                                                                0.004473
# rank_test_r2                                                                      3
#
#                                                                                34  \
# mean_fit_time                                                            1.517198
# std_fit_time                                                             0.103801
# mean_score_time                                                          0.125102
# std_score_time                                                           0.021635
# param_C                                                                        20
# param_gamma                                                                 scale
# param_kernel                                                                 poly
# params                              {'C': 20, 'gamma': 'scale', 'kernel': 'poly'}
# split0_test_neg_mean_squared_error                                 -671507.370099
# split1_test_neg_mean_squared_error                                 -714154.064524
# split2_test_neg_mean_squared_error                                -2212914.957116
# split3_test_neg_mean_squared_error                                -2330778.399989
# split4_test_neg_mean_squared_error                                 -545527.175142
# split5_test_neg_mean_squared_error                                -2338540.992517
# split6_test_neg_mean_squared_error                                 -2820726.50293
# split7_test_neg_mean_squared_error                                 -881117.071238
# split8_test_neg_mean_squared_error                                 -609315.231317
# split9_test_neg_mean_squared_error                                 -949970.030883
# mean_test_neg_mean_squared_error                                  -1407455.179576
# std_test_neg_mean_squared_error                                     851710.349172
# rank_test_neg_mean_squared_error                                               20
# split0_test_r2                                                           0.788235
# split1_test_r2                                                           0.742938
# split2_test_r2                                                           0.619545
# split3_test_r2                                                          -0.107593
# split4_test_r2                                                           0.552953
# split5_test_r2                                                           0.580939
# split6_test_r2                                                           0.594235
# split7_test_r2                                                          -0.109236
# split8_test_r2                                                           0.389781
# split9_test_r2                                                           0.745066
# mean_test_r2                                                             0.479686
# std_test_r2                                                              0.313535
# rank_test_r2                                                                   26
#
#                                                                                   35  \
# mean_fit_time                                                               1.822592
# std_fit_time                                                                0.123568
# mean_score_time                                                             0.142108
# std_score_time                                                              0.007193
# param_C                                                                           20
# param_gamma                                                                    scale
# param_kernel                                                                 sigmoid
# params                              {'C': 20, 'gamma': 'scale', 'kernel': 'sigmoid'}
# split0_test_neg_mean_squared_error                                   -2172102.912639
# split1_test_neg_mean_squared_error                                    -767269.349545
# split2_test_neg_mean_squared_error                                   -7251262.197118
# split3_test_neg_mean_squared_error                                   -2261208.737262
# split4_test_neg_mean_squared_error                                    -349446.761845
# split5_test_neg_mean_squared_error                                  -11075216.428001
# split6_test_neg_mean_squared_error                                  -19379227.563745
# split7_test_neg_mean_squared_error                                    -775993.464237
# split8_test_neg_mean_squared_error                                    -557665.205479
# split9_test_neg_mean_squared_error                                   -2291229.762065
# mean_test_neg_mean_squared_error                                     -4688062.238194
# std_test_neg_mean_squared_error                                       5896789.035783
# rank_test_neg_mean_squared_error                                                  40
# split0_test_r2                                                              0.315012
# split1_test_r2                                                              0.723819
# split2_test_r2                                                             -0.246672
# split3_test_r2                                                             -0.074533
# split4_test_r2                                                              0.713636
# split5_test_r2                                                             -0.984653
# split6_test_r2                                                             -1.787727
# split7_test_r2                                                              0.023104
# split8_test_r2                                                              0.441508
# split9_test_r2                                                              0.385125
# mean_test_r2                                                               -0.049138
# std_test_r2                                                                 0.753921
# rank_test_r2                                                                      40
#
#                                                                              36  \
# mean_fit_time                                                          1.743602
# std_fit_time                                                           0.053637
# mean_score_time                                                          0.3497
# std_score_time                                                         0.015639
# param_C                                                                      20
# param_gamma                                                                auto
# param_kernel                                                                rbf
# params                              {'C': 20, 'gamma': 'auto', 'kernel': 'rbf'}
# split0_test_neg_mean_squared_error                               -394627.977825
# split1_test_neg_mean_squared_error                               -149341.668857
# split2_test_neg_mean_squared_error                               -802786.012715
# split3_test_neg_mean_squared_error                               -187910.704289
# split4_test_neg_mean_squared_error                                -36409.974318
# split5_test_neg_mean_squared_error                               -576713.394939
# split6_test_neg_mean_squared_error                              -2051339.445972
# split7_test_neg_mean_squared_error                                -51571.405086
# split8_test_neg_mean_squared_error                               -102262.011604
# split9_test_neg_mean_squared_error                               -442803.034934
# mean_test_neg_mean_squared_error                                 -479576.563054
# std_test_neg_mean_squared_error                                   575237.550665
# rank_test_neg_mean_squared_error                                             11
# split0_test_r2                                                         0.875551
# split1_test_r2                                                         0.946244
# split2_test_r2                                                         0.861981
# split3_test_r2                                                         0.910704
# split4_test_r2                                                         0.970163
# split5_test_r2                                                         0.896654
# split6_test_r2                                                         0.704912
# split7_test_r2                                                         0.935077
# split8_test_r2                                                         0.897586
# split9_test_r2                                                         0.881169
# mean_test_r2                                                           0.888004
# std_test_r2                                                            0.068878
# rank_test_r2                                                                 11
#
#                                                                                 37  \
# mean_fit_time                                                             1.383898
# std_fit_time                                                               0.03241
# mean_score_time                                                             0.0891
# std_score_time                                                             0.00563
# param_C                                                                         20
# param_gamma                                                                   auto
# param_kernel                                                                linear
# params                              {'C': 20, 'gamma': 'auto', 'kernel': 'linear'}
# split0_test_neg_mean_squared_error                                   -13756.341915
# split1_test_neg_mean_squared_error                                    -9607.697111
# split2_test_neg_mean_squared_error                                   -28775.028611
# split3_test_neg_mean_squared_error                                   -13487.309235
# split4_test_neg_mean_squared_error                                   -11057.818584
# split5_test_neg_mean_squared_error                                   -12828.957647
# split6_test_neg_mean_squared_error                                   -15299.124809
# split7_test_neg_mean_squared_error                                   -12794.546696
# split8_test_neg_mean_squared_error                                   -11675.348188
# split9_test_neg_mean_squared_error                                    -43576.03895
# mean_test_neg_mean_squared_error                                     -17285.821175
# std_test_neg_mean_squared_error                                       10115.653755
# rank_test_neg_mean_squared_error                                                 3
# split0_test_r2                                                            0.995662
# split1_test_r2                                                            0.996542
# split2_test_r2                                                            0.995053
# split3_test_r2                                                            0.993591
# split4_test_r2                                                            0.990938
# split5_test_r2                                                            0.997701
# split6_test_r2                                                            0.997799
# split7_test_r2                                                            0.983893
# split8_test_r2                                                            0.988307
# split9_test_r2                                                            0.988306
# mean_test_r2                                                              0.992779
# std_test_r2                                                               0.004473
# rank_test_r2                                                                     3
#
#                                                                               38  \
# mean_fit_time                                                           1.386994
# std_fit_time                                                            0.113284
# mean_score_time                                                         0.102803
# std_score_time                                                           0.00556
# param_C                                                                       20
# param_gamma                                                                 auto
# param_kernel                                                                poly
# params                              {'C': 20, 'gamma': 'auto', 'kernel': 'poly'}
# split0_test_neg_mean_squared_error                                -672647.665241
# split1_test_neg_mean_squared_error                                -711526.606994
# split2_test_neg_mean_squared_error                               -2277081.193364
# split3_test_neg_mean_squared_error                               -2491687.133494
# split4_test_neg_mean_squared_error                                -540854.955949
# split5_test_neg_mean_squared_error                               -2385278.004564
# split6_test_neg_mean_squared_error                               -2633777.946793
# split7_test_neg_mean_squared_error                                 -772680.34874
# split8_test_neg_mean_squared_error                                -611587.816406
# split9_test_neg_mean_squared_error                                -944714.635953
# mean_test_neg_mean_squared_error                                  -1404183.63075
# std_test_neg_mean_squared_error                                    861245.242372
# rank_test_neg_mean_squared_error                                              19
# split0_test_r2                                                          0.787876
# split1_test_r2                                                          0.743884
# split2_test_r2                                                          0.608513
# split3_test_r2                                                         -0.184057
# split4_test_r2                                                          0.556782
# split5_test_r2                                                          0.572564
# split6_test_r2                                                          0.621128
# split7_test_r2                                                          0.027275
# split8_test_r2                                                          0.387505
# split9_test_r2                                                          0.746476
# mean_test_r2                                                            0.486794
# std_test_r2                                                             0.306652
# rank_test_r2                                                                  24
#
#                                                                                  39
# mean_fit_time                                                              1.723495
# std_fit_time                                                               0.080991
# mean_score_time                                                            0.143103
# std_score_time                                                             0.005703
# param_C                                                                          20
# param_gamma                                                                    auto
# param_kernel                                                                sigmoid
# params                              {'C': 20, 'gamma': 'auto', 'kernel': 'sigmoid'}
# split0_test_neg_mean_squared_error                                  -2220030.060676
# split1_test_neg_mean_squared_error                                   -849757.798475
# split2_test_neg_mean_squared_error                                  -6959737.208824
# split3_test_neg_mean_squared_error                                  -2532600.923526
# split4_test_neg_mean_squared_error                                   -416023.018912
# split5_test_neg_mean_squared_error                                  -9548240.364884
# split6_test_neg_mean_squared_error                                 -16338649.448416
# split7_test_neg_mean_squared_error                                  -1003007.142011
# split8_test_neg_mean_squared_error                                   -618533.500616
# split9_test_neg_mean_squared_error                                  -2148631.999414
# mean_test_neg_mean_squared_error                                    -4263521.146575
# std_test_neg_mean_squared_error                                      4929758.280793
# rank_test_neg_mean_squared_error                                                 37
# split0_test_r2                                                             0.299898
# split1_test_r2                                                             0.694127
# split2_test_r2                                                            -0.196552
# split3_test_r2                                                              -0.2035
# split4_test_r2                                                             0.659079
# split5_test_r2                                                            -0.711023
# split6_test_r2                                                            -1.350336
# split7_test_r2                                                            -0.262683
# split8_test_r2                                                             0.380549
# split9_test_r2                                                             0.423392
# mean_test_r2                                                              -0.026705
# std_test_r2                                                                 0.61653
# rank_test_r2                                                                     38
#
# [34 rows x 40 columns]

# %%
# getting all parameter combinations and their performance result
result = df[['param_C', 'param_gamma', 'param_kernel',
    'mean_test_r2', 'mean_test_neg_mean_squared_error']]
result.to_csv('performance_result_for_svr_gridsearchCV.csv')
print(result)
# Out:
#    param_C param_gamma param_kernel  mean_test_r2  \
# 0        1       scale          rbf     -0.030251
# 1        1       scale       linear      0.986478
# 2        1       scale         poly      0.339700
# 3        1       scale      sigmoid      0.488359
# 4        1        auto          rbf     -0.025830
# 5        1        auto       linear      0.986478
# 6        1        auto         poly      0.336841
# 7        1        auto      sigmoid      0.482479
# 8        5       scale          rbf      0.599963
# 9        5       scale       linear      0.992567
# 10       5       scale         poly      0.421124
# 11       5       scale      sigmoid      0.848384
# 12       5        auto          rbf      0.611574
# 13       5        auto       linear      0.992567
# 14       5        auto         poly      0.412273
# 15       5        auto      sigmoid      0.861315
# 16      10       scale          rbf      0.780019
# 17      10       scale       linear      0.992773
# 18      10       scale         poly      0.439606
# 19      10       scale      sigmoid      0.666240
# 20      10        auto          rbf      0.787237
# 21      10        auto       linear      0.992773
# 22      10        auto         poly      0.445358
# 23      10        auto      sigmoid      0.675320
# 24      15       scale          rbf      0.850216
# 25      15       scale       linear      0.992793
# 26      15       scale         poly      0.462012
# 27      15       scale      sigmoid      0.363826
# 28      15        auto          rbf      0.855046
# 29      15        auto       linear      0.992793
# 30      15        auto         poly      0.473042
# 31      15        auto      sigmoid      0.372248
# 32      20       scale          rbf      0.884029
# 33      20       scale       linear      0.992779
# 34      20       scale         poly      0.479686
# 35      20       scale      sigmoid     -0.049138
# 36      20        auto          rbf      0.888004
# 37      20        auto       linear      0.992779
# 38      20        auto         poly      0.486794
# 39      20        auto      sigmoid     -0.026705
#
#     mean_test_neg_mean_squared_error
# 0                      -4.343214e+06
# 1                      -3.554237e+04
# 2                      -1.970571e+06
# 3                      -2.161411e+06
# 4                      -4.312471e+06
# 5                      -3.554237e+04
# 6                      -2.017890e+06
# 7                      -2.236357e+06
# 8                      -1.862969e+06
# 9                      -1.811091e+04
# 10                     -1.570702e+06
# 11                     -7.345416e+05
# 12                     -1.779606e+06
# 13                     -1.811091e+04
# 14                     -1.622316e+06
# 15                     -6.387287e+05
# 16                     -1.013445e+06
# 17                     -1.736635e+04
# 18                     -1.454104e+06
# 19                     -1.566332e+06
# 20                     -9.612721e+05
# 21                     -1.736635e+04
# 22                     -1.466036e+06
# 23                     -1.436220e+06
# 24                     -6.719733e+05
# 25                     -1.726752e+04
# 26                     -1.412748e+06
# 27                     -2.913465e+06
# 28                     -6.362464e+05
# 29                     -1.726752e+04
# 30                     -1.412592e+06
# 31                     -2.673164e+06
# 32                     -5.092499e+05
# 33                     -1.728582e+04
# 34                     -1.407455e+06
# 35                     -4.688062e+06
# 36                     -4.795766e+05
# 37                     -1.728582e+04
# 38                     -1.404184e+06
# 39                     -4.263521e+06

# %%
# printing the best combination of parameter that perform the best
print(regr.best_params_)

# the best performing score
print(regr.best_score_)
# Out:
# {'C': 15, 'gamma': 'scale', 'kernel': 'linear'}
# 0.992793249592254

# %% [markdown]
# ### Prediction

# %% [markdown]
# ### Saving trained model to a file and reading the same file using pickle module

# %%
# import pickle

# with open('trained_svm_model', 'wb') as f:
#    pickle.dump(regressor, f)

#with open('trained_svm_model', 'rb') as f:
#    mp = pickle.load(f)
#    mp.predict(X)

# %% [markdown]
# ### Another approach for saving and reading the trained model using joblib module
# - It is more efficient on objects that carry large numpy arrays internally as is often the case for fitted scikit-learn estimators

# %%
#from sklearn.externals import joblib
#from joblib import dump, load
#dump(regressor, 'trained_svm_model.joblib') 

#clf = load('trained_svm_model.joblib')
